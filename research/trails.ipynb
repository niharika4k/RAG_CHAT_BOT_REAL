# %%
print ("ok")
# Out:
# ok

# %%
# %pwd
# Out:
# 'c:\\Users\\nihar\\Documents\\RAG_Chat_bot\\RAG_CHAT_BOT_REAL\\research'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\nihar\\Documents\\RAG_Chat_bot\\RAG_CHAT_BOT_REAL'
